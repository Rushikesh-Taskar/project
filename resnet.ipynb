# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow_addons as tfa
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D


print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.13.0

# %%
WORK_DIR = './Alzheimer_s Dataset'

CLASSES = [ 'NonDemented',
            'VeryMildDemented',
            'MildDemented',
            'ModerateDemented']

IMG_SIZE = 176
IMAGE_SIZE = [176, 176]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 6400 images belonging to 4 classes.

# %%
def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    labels =dict(zip([0,1,2,3], CLASSES))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)

# %%
train_data, train_labels = train_data_gen.next()

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (6400, 176, 176, 3) (6400, 4)

# %%
sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)
# Out:
# (12800, 176, 176, 3) (12800, 4)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
resnet_model = ResNet50(input_shape=(176, 176, 3), include_top=False, weights="imagenet")

# %%
for layer in resnet_model.layers:
    layer.trainable=False

# %%
custom_resnet_model = Sequential([
        resnet_model,
        Dropout(0.5),
        GlobalAveragePooling2D(),
        Flatten(),
        BatchNormalization(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        BatchNormalization(),
        Dense(4, activation='softmax')        
    ], name = "resnet_cnn_model")

# %%
import keras.backend as K
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# CALLBACKS = rop_callback
    
custom_resnet_model.compile(optimizer='rmsprop',
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=METRICS)

custom_resnet_model.summary()
# Out:
# Model: "resnet_cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 6, 6, 2048)        23587712
#
#  dropout_5 (Dropout)         (None, 6, 6, 2048)        0
#
#  global_average_pooling2d_1  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  batch_normalization_5 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  dense_5 (Dense)             (None, 512)               1049088
#
#  batch_normalization_6 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  batch_normalization_7 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  batch_normalization_8 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  batch_normalization_9 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_9 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 24821572 (94.69 MB)
# Trainable params: 1227844 (4.68 MB)
# Non-trainable params: 23593728 (90.00 MB)
# _________________________________________________________________

# %%
EPOCHS = 20

history = custom_resnet_model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=EPOCHS,steps_per_epoch=256)
# Out:
# Epoch 1/20
# 256/256 [==============================] - 284s 1s/step - loss: 1.6946 - accuracy: 0.6917 - precision: 0.2692 - recall: 0.1361 - auc: 0.5264 - f1_score: 0.1791 - val_loss: 1.3640 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5782 - val_f1_score: 0.0000e+00
# Epoch 2/20
# 256/256 [==============================] - 262s 1s/step - loss: 1.4472 - accuracy: 0.7341 - precision: 0.4033 - recall: 0.1329 - auc: 0.5874 - f1_score: 0.1965 - val_loss: 1.2570 - val_accuracy: 0.7562 - val_precision: 0.9310 - val_recall: 0.0269 - val_auc: 0.6936 - val_f1_score: 0.0502
# Epoch 3/20
# 256/256 [==============================] - 263s 1s/step - loss: 1.3025 - accuracy: 0.7556 - precision: 0.5384 - recall: 0.1576 - auc: 0.6627 - f1_score: 0.2409 - val_loss: 1.1358 - val_accuracy: 0.7789 - val_precision: 0.7197 - val_recall: 0.1892 - val_auc: 0.7564 - val_f1_score: 0.2921
# Epoch 4/20
# 256/256 [==============================] - 237s 926ms/step - loss: 1.2224 - accuracy: 0.7667 - precision: 0.6062 - recall: 0.1911 - auc: 0.7092 - f1_score: 0.2882 - val_loss: 1.0459 - val_accuracy: 0.7931 - val_precision: 0.7552 - val_recall: 0.2550 - val_auc: 0.8021 - val_f1_score: 0.3741
# Epoch 5/20
# 256/256 [==============================] - 247s 964ms/step - loss: 1.1900 - accuracy: 0.7687 - precision: 0.6164 - recall: 0.1979 - auc: 0.7281 - f1_score: 0.2978 - val_loss: 1.0658 - val_accuracy: 0.7841 - val_precision: 0.7866 - val_recall: 0.1873 - val_auc: 0.7895 - val_f1_score: 0.2967
# Epoch 6/20
# 256/256 [==============================] - 316s 1s/step - loss: 1.1614 - accuracy: 0.7764 - precision: 0.6581 - recall: 0.2196 - auc: 0.7446 - f1_score: 0.3267 - val_loss: 0.9859 - val_accuracy: 0.8040 - val_precision: 0.8182 - val_recall: 0.2779 - val_auc: 0.8261 - val_f1_score: 0.4046
# Epoch 7/20
# 256/256 [==============================] - 433s 2s/step - loss: 1.1253 - accuracy: 0.7819 - precision: 0.6785 - recall: 0.2424 - auc: 0.7624 - f1_score: 0.3541 - val_loss: 0.9412 - val_accuracy: 0.8140 - val_precision: 0.8482 - val_recall: 0.3118 - val_auc: 0.8411 - val_f1_score: 0.4480
# Epoch 8/20
# 256/256 [==============================] - 495s 2s/step - loss: 1.1114 - accuracy: 0.7810 - precision: 0.6656 - recall: 0.2490 - auc: 0.7721 - f1_score: 0.3604 - val_loss: 0.9225 - val_accuracy: 0.8113 - val_precision: 0.8417 - val_recall: 0.3018 - val_auc: 0.8454 - val_f1_score: 0.4360
# Epoch 9/20
# 256/256 [==============================] - 460s 2s/step - loss: 1.0976 - accuracy: 0.7860 - precision: 0.6964 - recall: 0.2556 - auc: 0.7761 - f1_score: 0.3707 - val_loss: 0.9037 - val_accuracy: 0.8127 - val_precision: 0.8316 - val_recall: 0.3147 - val_auc: 0.8509 - val_f1_score: 0.4509
# Epoch 10/20
# 256/256 [==============================] - 452s 2s/step - loss: 1.0886 - accuracy: 0.7855 - precision: 0.6747 - recall: 0.2746 - auc: 0.7807 - f1_score: 0.3879 - val_loss: 0.8962 - val_accuracy: 0.8162 - val_precision: 0.8464 - val_recall: 0.3237 - val_auc: 0.8593 - val_f1_score: 0.4659
# Epoch 11/20
# 256/256 [==============================] - 410s 2s/step - loss: 1.0752 - accuracy: 0.7871 - precision: 0.6755 - recall: 0.2854 - auc: 0.7875 - f1_score: 0.3976 - val_loss: 0.9181 - val_accuracy: 0.8108 - val_precision: 0.8228 - val_recall: 0.3098 - val_auc: 0.8518 - val_f1_score: 0.4448
# Epoch 12/20
# 256/256 [==============================] - 372s 1s/step - loss: 1.0658 - accuracy: 0.7905 - precision: 0.6857 - recall: 0.2990 - auc: 0.7902 - f1_score: 0.4136 - val_loss: 0.8940 - val_accuracy: 0.8125 - val_precision: 0.8177 - val_recall: 0.3217 - val_auc: 0.8580 - val_f1_score: 0.4566
# Epoch 13/20
# 256/256 [==============================] - 215s 840ms/step - loss: 1.0474 - accuracy: 0.7925 - precision: 0.6881 - recall: 0.3105 - auc: 0.7981 - f1_score: 0.4250 - val_loss: 0.8563 - val_accuracy: 0.8212 - val_precision: 0.8164 - val_recall: 0.3675 - val_auc: 0.8636 - val_f1_score: 0.5009
# Epoch 14/20
# 256/256 [==============================] - 216s 844ms/step - loss: 1.0605 - accuracy: 0.7901 - precision: 0.6756 - recall: 0.3088 - auc: 0.7964 - f1_score: 0.4209 - val_loss: 0.8746 - val_accuracy: 0.8187 - val_precision: 0.8108 - val_recall: 0.3586 - val_auc: 0.8679 - val_f1_score: 0.4908
# Epoch 15/20
# 256/256 [==============================] - 217s 849ms/step - loss: 1.0499 - accuracy: 0.7913 - precision: 0.6760 - recall: 0.3171 - auc: 0.7971 - f1_score: 0.4291 - val_loss: 0.8675 - val_accuracy: 0.8185 - val_precision: 0.8412 - val_recall: 0.3376 - val_auc: 0.8670 - val_f1_score: 0.4762
# Epoch 16/20
# 256/256 [==============================] - 218s 854ms/step - loss: 1.0243 - accuracy: 0.7967 - precision: 0.6933 - recall: 0.3352 - auc: 0.8080 - f1_score: 0.4496 - val_loss: 0.8451 - val_accuracy: 0.8217 - val_precision: 0.8429 - val_recall: 0.3526 - val_auc: 0.8765 - val_f1_score: 0.4901
# Epoch 17/20
# 256/256 [==============================] - 222s 868ms/step - loss: 1.0232 - accuracy: 0.7997 - precision: 0.7038 - recall: 0.3430 - auc: 0.8089 - f1_score: 0.4577 - val_loss: 0.8260 - val_accuracy: 0.8274 - val_precision: 0.8116 - val_recall: 0.4034 - val_auc: 0.8781 - val_f1_score: 0.5358
# Epoch 18/20
# 256/256 [==============================] - 221s 864ms/step - loss: 1.0298 - accuracy: 0.7951 - precision: 0.6839 - recall: 0.3357 - auc: 0.8060 - f1_score: 0.4469 - val_loss: 0.8387 - val_accuracy: 0.8254 - val_precision: 0.8359 - val_recall: 0.3755 - val_auc: 0.8756 - val_f1_score: 0.5135
# Epoch 19/20
# 256/256 [==============================] - 218s 851ms/step - loss: 1.0164 - accuracy: 0.8008 - precision: 0.7158 - recall: 0.3367 - auc: 0.8132 - f1_score: 0.4544 - val_loss: 0.8184 - val_accuracy: 0.8267 - val_precision: 0.8548 - val_recall: 0.3695 - val_auc: 0.8803 - val_f1_score: 0.5130
# Epoch 20/20
# 156/256 [=================>............] - ETA: 1:13 - loss: 1.0273 - accuracy: 0.8010 - precision: 0.6974 - recall: 0.3606 - auc: 0.8090 - f1_score: 0.4723WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 5120 batches). You may need to use the repeat() function when building your dataset.
# 256/256 [==============================] - 163s 637ms/step - loss: 1.0273 - accuracy: 0.8010 - precision: 0.6974 - recall: 0.3606 - auc: 0.8090 - f1_score: 0.4723 - val_loss: 0.8338 - val_accuracy: 0.8250 - val_precision: 0.8129 - val_recall: 0.3894 - val_auc: 0.8740 - val_f1_score: 0.5234

# %%
#Evaluating the model on the data

#train_scores = model.evaluate(train_data, train_labels)
#val_scores = model.evaluate(val_data, val_labels)
test_scores = custom_resnet_model.evaluate(test_data, test_labels)

#print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
#print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 40/40 [==============================] - 50s 1s/step - loss: 0.8029 - accuracy: 0.8357 - precision: 0.8632 - recall: 0.4072 - auc: 0.8900 - f1_score: 0.5462
# Testing Accuracy: 83.57%

# %%
pred_labels = custom_resnet_model.predict(test_data)
# Out:
# 40/40 [==============================] - 46s 1s/step

# %%
#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=CLASSES))
# Out:
#                   precision    recall  f1-score   support
#
#      NonDemented       0.50      0.82      0.62       311
# VeryMildDemented       0.85      0.99      0.91       313
#     MildDemented       0.63      0.61      0.62       323
# ModerateDemented       0.41      0.09      0.15       308
#
#        micro avg       0.63      0.63      0.63      1255
#        macro avg       0.60      0.63      0.58      1255
#     weighted avg       0.60      0.63      0.58      1255
#      samples avg       0.63      0.63      0.63      1255

# %%
import pickle
# save the iris classification model as a pickle file
model_pkl_file = "resnet.pkl"  
with open(model_pkl_file, 'wb') as file:  
    pickle.dump(custom_resnet_model, file)

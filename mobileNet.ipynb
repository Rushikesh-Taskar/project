# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow_addons as tfa
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.applications.mobilenet import MobileNet

print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.13.0

# %%
WORK_DIR = './Alzheimers-ADNI'

CLASSES = [ 'Final AD JPEG', 'Final CN JPEG', 'Final EMCI JPEG', 'Final LMCI JPEG', 'Final MCI JPEG']

IMG_SIZE = 176
IMAGE_SIZE = [176, 176]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 1296 images belonging to 5 classes.

# %%
def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    labels =dict(zip([0,1,2,3,4], CLASSES))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 1296)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)

# %%
train_data, train_labels = train_data_gen.next()

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (1296, 176, 176, 3) (1296, 5)

# %%
sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)
# Out:
# (2900, 176, 176, 3) (2900, 5)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
mobilenet_model = MobileNet(input_shape=(176, 176, 3), include_top=False, weights="imagenet")
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
for layer in mobilenet_model.layers:
    layer.trainable=False

# %%
custom_mobilenet_model = Sequential([
        mobilenet_model,
        Dropout(0.5),
        GlobalAveragePooling2D(),
        Flatten(),
        BatchNormalization(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        BatchNormalization(),
        Dense(5, activation='softmax')        
    ], name = "mobilenet_model")

# %%
import keras.backend as K
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# CALLBACKS = rop_callback
    
custom_mobilenet_model.compile(optimizer='rmsprop',
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=METRICS)

custom_mobilenet_model.summary()
# Out:
# Model: "mobilenet_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functi  (None, 5, 5, 1024)        3228864
#  onal)
#
#  dropout_5 (Dropout)         (None, 5, 5, 1024)        0
#
#  global_average_pooling2d_1  (None, 1024)              0
#   (GlobalAveragePooling2D)
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  batch_normalization_5 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dense_5 (Dense)             (None, 512)               524800
#
#  batch_normalization_6 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  batch_normalization_7 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  batch_normalization_8 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  batch_normalization_9 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_9 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 3934405 (15.01 MB)
# Trainable params: 701573 (2.68 MB)
# Non-trainable params: 3232832 (12.33 MB)
# _________________________________________________________________

# %%
EPOCHS = 20

history = custom_mobilenet_model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=EPOCHS,steps_per_epoch=256)
# Out:
# Epoch 1/20
# 256/256 [==============================] - 48s 186ms/step - loss: 1.2500 - accuracy: 0.8211 - precision: 0.6421 - recall: 0.2383 - auc: 0.7922 - f1_score: 0.3403 - val_loss: 1.1202 - val_accuracy: 0.8379 - val_precision: 0.7529 - val_recall: 0.2823 - val_auc: 0.8362 - val_f1_score: 0.3987
# Epoch 2/20
# 256/256 [==============================] - 76s 297ms/step - loss: 1.2400 - accuracy: 0.8249 - precision: 0.6680 - recall: 0.2476 - auc: 0.7938 - f1_score: 0.3512 - val_loss: 1.0806 - val_accuracy: 0.8414 - val_precision: 0.7474 - val_recall: 0.3125 - val_auc: 0.8514 - val_f1_score: 0.4277
# Epoch 3/20
# 256/256 [==============================] - 76s 298ms/step - loss: 1.2087 - accuracy: 0.8293 - precision: 0.6769 - recall: 0.2803 - auc: 0.8055 - f1_score: 0.3885 - val_loss: 1.0492 - val_accuracy: 0.8427 - val_precision: 0.7368 - val_recall: 0.3319 - val_auc: 0.8607 - val_f1_score: 0.4438
# Epoch 4/20
# 256/256 [==============================] - 75s 295ms/step - loss: 1.1950 - accuracy: 0.8303 - precision: 0.6718 - recall: 0.2959 - auc: 0.8124 - f1_score: 0.4025 - val_loss: 1.0169 - val_accuracy: 0.8453 - val_precision: 0.7586 - val_recall: 0.3319 - val_auc: 0.8697 - val_f1_score: 0.4438
# Epoch 5/20
# 256/256 [==============================] - 75s 294ms/step - loss: 1.1955 - accuracy: 0.8312 - precision: 0.6706 - recall: 0.3062 - auc: 0.8127 - f1_score: 0.4109 - val_loss: 0.9877 - val_accuracy: 0.8534 - val_precision: 0.7981 - val_recall: 0.3578 - val_auc: 0.8786 - val_f1_score: 0.4790
# Epoch 6/20
# 256/256 [==============================] - 75s 295ms/step - loss: 1.1748 - accuracy: 0.8303 - precision: 0.6588 - recall: 0.3140 - auc: 0.8190 - f1_score: 0.4168 - val_loss: 0.9785 - val_accuracy: 0.8578 - val_precision: 0.7815 - val_recall: 0.4009 - val_auc: 0.8810 - val_f1_score: 0.5166
# Epoch 7/20
# 256/256 [==============================] - 78s 305ms/step - loss: 1.1531 - accuracy: 0.8373 - precision: 0.6812 - recall: 0.3506 - auc: 0.8280 - f1_score: 0.4564 - val_loss: 0.9757 - val_accuracy: 0.8513 - val_precision: 0.7668 - val_recall: 0.3685 - val_auc: 0.8830 - val_f1_score: 0.4937
# Epoch 8/20
# 256/256 [==============================] - 77s 301ms/step - loss: 1.1366 - accuracy: 0.8356 - precision: 0.6679 - recall: 0.3545 - auc: 0.8330 - f1_score: 0.4568 - val_loss: 0.9529 - val_accuracy: 0.8547 - val_precision: 0.7635 - val_recall: 0.3966 - val_auc: 0.8862 - val_f1_score: 0.5109
# Epoch 9/20
# 256/256 [==============================] - 75s 294ms/step - loss: 1.1221 - accuracy: 0.8404 - precision: 0.6868 - recall: 0.3716 - auc: 0.8375 - f1_score: 0.4737 - val_loss: 0.9243 - val_accuracy: 0.8642 - val_precision: 0.8282 - val_recall: 0.4052 - val_auc: 0.8944 - val_f1_score: 0.5311
# Epoch 10/20
# 256/256 [==============================] - 38s 149ms/step - loss: 1.0690 - accuracy: 0.8453 - precision: 0.6986 - recall: 0.3984 - auc: 0.8533 - f1_score: 0.4993 - val_loss: 0.9151 - val_accuracy: 0.8672 - val_precision: 0.7977 - val_recall: 0.4504 - val_auc: 0.8945 - val_f1_score: 0.5682
# Epoch 11/20
# 256/256 [==============================] - 31s 122ms/step - loss: 1.0647 - accuracy: 0.8456 - precision: 0.6931 - recall: 0.4092 - auc: 0.8547 - f1_score: 0.5060 - val_loss: 0.9048 - val_accuracy: 0.8711 - val_precision: 0.8044 - val_recall: 0.4698 - val_auc: 0.8984 - val_f1_score: 0.5900
# Epoch 12/20
# 256/256 [==============================] - 31s 121ms/step - loss: 1.0713 - accuracy: 0.8450 - precision: 0.6903 - recall: 0.4082 - auc: 0.8528 - f1_score: 0.5054 - val_loss: 0.9115 - val_accuracy: 0.8638 - val_precision: 0.7606 - val_recall: 0.4655 - val_auc: 0.8959 - val_f1_score: 0.5666
# Epoch 13/20
# 256/256 [==============================] - 31s 122ms/step - loss: 1.0102 - accuracy: 0.8507 - precision: 0.6967 - recall: 0.4487 - auc: 0.8696 - f1_score: 0.5409 - val_loss: 0.8776 - val_accuracy: 0.8741 - val_precision: 0.7848 - val_recall: 0.5108 - val_auc: 0.9027 - val_f1_score: 0.6147
# Epoch 14/20
# 256/256 [==============================] - 31s 123ms/step - loss: 1.0119 - accuracy: 0.8577 - precision: 0.7184 - recall: 0.4746 - auc: 0.8698 - f1_score: 0.5634 - val_loss: 0.8901 - val_accuracy: 0.8724 - val_precision: 0.7710 - val_recall: 0.5151 - val_auc: 0.9011 - val_f1_score: 0.6163
# Epoch 15/20
# 256/256 [==============================] - 31s 123ms/step - loss: 1.0301 - accuracy: 0.8528 - precision: 0.6956 - recall: 0.4697 - auc: 0.8648 - f1_score: 0.5536 - val_loss: 0.8756 - val_accuracy: 0.8724 - val_precision: 0.7745 - val_recall: 0.5108 - val_auc: 0.9037 - val_f1_score: 0.6090
# Epoch 16/20
# 256/256 [==============================] - 31s 122ms/step - loss: 0.9898 - accuracy: 0.8576 - precision: 0.7132 - recall: 0.4819 - auc: 0.8755 - f1_score: 0.5690 - val_loss: 0.8763 - val_accuracy: 0.8707 - val_precision: 0.7680 - val_recall: 0.5065 - val_auc: 0.9053 - val_f1_score: 0.6085
# Epoch 17/20
# 256/256 [==============================] - 32s 123ms/step - loss: 0.9468 - accuracy: 0.8631 - precision: 0.7212 - recall: 0.5142 - auc: 0.8865 - f1_score: 0.5962 - val_loss: 0.8582 - val_accuracy: 0.8784 - val_precision: 0.7758 - val_recall: 0.5517 - val_auc: 0.9083 - val_f1_score: 0.6424
# Epoch 18/20
# 256/256 [==============================] - 31s 122ms/step - loss: 0.9642 - accuracy: 0.8631 - precision: 0.7203 - recall: 0.5156 - auc: 0.8824 - f1_score: 0.5966 - val_loss: 0.8353 - val_accuracy: 0.8841 - val_precision: 0.7946 - val_recall: 0.5668 - val_auc: 0.9142 - val_f1_score: 0.6557
# Epoch 19/20
#  32/256 [==>...........................] - ETA: 23s - loss: 1.0290 - accuracy: 0.8500 - precision: 0.6702 - recall: 0.4922 - auc: 0.8645 - f1_score: 0.5652WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 5120 batches). You may need to use the repeat() function when building your dataset.
# 256/256 [==============================] - 9s 33ms/step - loss: 1.0290 - accuracy: 0.8500 - precision: 0.6702 - recall: 0.4922 - auc: 0.8645 - f1_score: 0.5652 - val_loss: 0.8612 - val_accuracy: 0.8828 - val_precision: 0.7743 - val_recall: 0.5841 - val_auc: 0.9096 - val_f1_score: 0.6616

# %%
#Evaluating the model on the data

#train_scores = model.evaluate(train_data, train_labels)
#val_scores = model.evaluate(val_data, val_labels)
test_scores = custom_mobilenet_model.evaluate(test_data, test_labels)

#print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
#print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 19/19 [==============================] - 6s 310ms/step - loss: 0.8207 - accuracy: 0.8969 - precision: 0.8337 - recall: 0.6052 - auc: 0.9167 - f1_score: 0.6850
# Testing Accuracy: 89.69%

# %%
pred_labels = custom_mobilenet_model.predict(test_data)
# Out:
# 19/19 [==============================] - 6s 306ms/step

# %%
#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=CLASSES))
# Out:
#                  precision    recall  f1-score   support
#
#   Final AD JPEG       0.76      0.71      0.74       112
#   Final CN JPEG       0.65      0.54      0.59       125
# Final EMCI JPEG       0.68      0.70      0.69       117
# Final LMCI JPEG       0.87      0.93      0.90       116
#  Final MCI JPEG       0.56      0.65      0.60       110
#
#       micro avg       0.71      0.71      0.71       580
#       macro avg       0.71      0.71      0.70       580
#    weighted avg       0.71      0.71      0.70       580
#     samples avg       0.71      0.71      0.71       580

# %%
import pickle
# save the iris classification model as a pickle file
model_pkl_file = "mobilenetAdni.pkl"  
with open(model_pkl_file, 'wb') as file:  
    pickle.dump(custom_mobilenet_model, file)
